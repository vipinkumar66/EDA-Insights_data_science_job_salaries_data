# %% [markdown]
# # ABOUT NAAC
# The NATIONAL ASSESSMENT AND ACCREDITATION COUNCIL (NAAC) conducts assessment and accreditation of Higher Educational Institutions (HEI) such as colleges, universities or other recognised institutions to derive an understanding of the ‘Quality Status’ of the institution. NAAC evaluates the institutions for its conformance to the standards of quality in terms of its performance related to the educational processes and outcomes, curriculum coverage, teaching-learning processes, faculty, research, infrastructure, learning resources, organisation, governance, financial well being and student services.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r'F:\DO YOU HAVE IT IN YOU\python homework\NAAC accreditation of Institutions.csv')

# %%
df
# Out:
#       Unnamed: 0 National Assessment and Accreditation Council, Bengaluru  \
# 0            NaN                                                NaN
# 1            NaN  Colleges accredited by NAAC having valid accre...
# 2            NaN                                                NaN
# 3            NaN                                            Sr. No.
# 4            NaN                                                  1
# ...          ...                                                ...
# 6200         NaN                                               6197
# 6201         NaN                                               6198
# 6202         NaN                                               6199
# 6203         NaN                                               6200
# 6204         NaN                                               6201
#
#                                              Unnamed: 2  \
# 0                                                   NaN
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 National Assessment and Accreditation Council, Bengaluru  \
# 0         NaN                                                NaN
# 1         NaN  Colleges accredited by NAAC having valid accre...
# 2         NaN                                                NaN
# 3         NaN                                            Sr. No.
# 4         NaN                                                  1
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                Name of the College
# 4  MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
#
#                     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                          NaN        NaN        NaN
# 1                          NaN        NaN        NaN
# 2                          NaN        NaN        NaN
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 National Assessment and Accreditation Council, Bengaluru  \
# 6200         NaN                                               6197
# 6201         NaN                                               6198
# 6202         NaN                                               6199
# 6203         NaN                                               6200
# 6204         NaN                                               6201
#
#                                              Unnamed: 2    Unnamed: 3  \
# 6200  Khandra College,P.O.- Khandra, P.S. Andal, Dis...  West Bengal
# 6201  Katwa College,Dukbanglow Road, Purba Bardhaman...  West Bengal
# 6202  NSHM Knowledge Campus, Kolkata - Group of Inst...  West Bengal
# 6203  SAHEED NURUL ISLAM MAHAVIDYALAYA,GOKULPUR-HARI...  West Bengal
# 6204  SALESIAN COLLEGE,SONADA PO SONADA DARJEELING,S...  West Bengal
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0',
#        'National Assessment and Accreditation Council, Bengaluru',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 National Assessment and Accreditation Council, Bengaluru  \
# 0            NaN                                                NaN
# 1            NaN  Colleges accredited by NAAC having valid accre...
# 2            NaN                                                NaN
# 3            NaN                                            Sr. No.
# 4            NaN                                                  1
# ...          ...                                                ...
# 6200         NaN                                               6197
# 6201         NaN                                               6198
# 6202         NaN                                               6199
# 6203         NaN                                               6200
# 6204         NaN                                               6201
#
#                                              Unnamed: 2  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                  6205
# National Assessment and Accreditation Council, Bengaluru       2
# Unnamed: 2                                                     3
# Unnamed: 3                                                     3
# Unnamed: 4                                                     3
#                                                             ...
# Unnamed: 83                                                 6205
# Unnamed: 84                                                 6205
# Unnamed: 85                                                 6205
# Unnamed: 86                                                 6205
# Unnamed: 87                                                 6205
# Length: 88, dtype: int64

# %%
#so let's drop the rows and columns not imp for us 
df.drop([0,1,2,3],inplace=True)
df.drop(df.iloc[:,7:88], inplace= True, axis=1)
df.drop(df.columns[0], inplace=True, axis=1)
df.columns
# Out:
# Index(['National Assessment and Accreditation Council, Bengaluru',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df.head()
# Out:
#   National Assessment and Accreditation Council, Bengaluru  \
# 4                                                  1
# 5                                                  2
# 6                                                  3
# 7                                                  4
# 8                                                  5
#
#                                           Unnamed: 2  \
# 4  MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
# 5  Jawaharlal Nehru Rajkeeya Mahavidyalaya, Port ...
# 6  Dr. B. R. Ambedkar Institute of Technology (Fi...
# 7  Aditya College of Engineering and Technology K...
# 8  Aditya Engineering College  Dist. East Godavar...
#
#                     Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 4  Andaman and Nicobar Islands       1.88          C  22-02-2026
# 5  Andaman and Nicobar Islands       3.01          A  04-11-2021
# 6  Andaman and Nicobar Islands       2.61         B+  02-07-2023
# ...

# %%
#Now lets rename our columns, for better clarity
df.rename(columns={'Unnamed: 2':'college name', 'Unnamed: 3':'state', 'Unnamed: 4':'CGPA', 'Unnamed: 5':'GRADE', 'Unnamed: 6':'Accreditation validity'},inplace=True )

# %%
df.columns
# Out:
# Index(['National Assessment and Accreditation Council, Bengaluru',
#        'college name', 'state', 'CGPA', 'GRADE', 'Accreditation validity'],
#       dtype='object')

# %%
df.head()
# Out:
#   National Assessment and Accreditation Council, Bengaluru  \
# 4                                                  1
# 5                                                  2
# 6                                                  3
# 7                                                  4
# 8                                                  5
#
#                                         college name  \
# 4  MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
# 5  Jawaharlal Nehru Rajkeeya Mahavidyalaya, Port ...
# 6  Dr. B. R. Ambedkar Institute of Technology (Fi...
# 7  Aditya College of Engineering and Technology K...
# 8  Aditya Engineering College  Dist. East Godavar...
#
#                          state  CGPA GRADE Accreditation validity
# 4  Andaman and Nicobar Islands  1.88     C             22-02-2026
# 5  Andaman and Nicobar Islands  3.01     A             04-11-2021
# 6  Andaman and Nicobar Islands  2.61    B+             02-07-2023
# ...

# %%
df['college name']= df['college name'].apply(lambda x:x.upper())

# %%
df['college name']
# Out:
# 4       MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
# 5       JAWAHARLAL NEHRU RAJKEEYA MAHAVIDYALAYA, PORT ...
# 6       DR. B. R. AMBEDKAR INSTITUTE OF TECHNOLOGY (FI...
# 7       ADITYA COLLEGE OF ENGINEERING AND TECHNOLOGY K...
# 8       ADITYA ENGINEERING COLLEGE  DIST. EAST GODAVAR...
#                               ...
# 6200    KHANDRA COLLEGE,P.O.- KHANDRA, P.S. ANDAL, DIS...
# 6201    KATWA COLLEGE,DUKBANGLOW ROAD, PURBA BARDHAMAN...
# 6202    NSHM KNOWLEDGE CAMPUS, KOLKATA - GROUP OF INST...
# 6203    SAHEED NURUL ISLAM MAHAVIDYALAYA,GOKULPUR-HARI...
# 6204    SALESIAN COLLEGE,SONADA PO SONADA DARJEELING,S...
# Name: college name, Length: 6201, dtype: object

# %%
df.rename(columns={'National Assessment and Accreditation Council, Bengaluru': 'Sr.No.'}, inplace=True)

# %%
df.head()
# Out:
#   Sr.No.                                       college name  \
# 4      1  MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
# 5      2  JAWAHARLAL NEHRU RAJKEEYA MAHAVIDYALAYA, PORT ...
# 6      3  DR. B. R. AMBEDKAR INSTITUTE OF TECHNOLOGY (FI...
# 7      4  ADITYA COLLEGE OF ENGINEERING AND TECHNOLOGY K...
# 8      5  ADITYA ENGINEERING COLLEGE  DIST. EAST GODAVAR...
#
#                          state  CGPA GRADE Accreditation validity
# 4  Andaman and Nicobar Islands  1.88     C             22-02-2026
# 5  Andaman and Nicobar Islands  3.01     A             04-11-2021
# 6  Andaman and Nicobar Islands  2.61    B+             02-07-2023
# 7               Andhra Pradesh  2.68     B             10-07-2021
# 8               Andhra Pradesh  3.11     A             30-04-2020

# %%
df.set_index('Sr.No.', inplace=True)

# %%
df.head()
# Out:
#                                              college name  \
# Sr.No.
# 1       MAHATMA GANDHI GOVERNMENT COLLEGE, MAHATMA GAN...
# 2       JAWAHARLAL NEHRU RAJKEEYA MAHAVIDYALAYA, PORT ...
# 3       DR. B. R. AMBEDKAR INSTITUTE OF TECHNOLOGY (FI...
# 4       ADITYA COLLEGE OF ENGINEERING AND TECHNOLOGY K...
# 5       ADITYA ENGINEERING COLLEGE  DIST. EAST GODAVAR...
#
#                               state  CGPA GRADE Accreditation validity
# Sr.No.
# 1       Andaman and Nicobar Islands  1.88     C             22-02-2026
# 2       Andaman and Nicobar Islands  3.01     A             04-11-2021
# 3       Andaman and Nicobar Islands  2.61    B+             02-07-2023
# 4                    Andhra Pradesh  2.68     B             10-07-2021
# 5                    Andhra Pradesh  3.11     A             30-04-2020

# %% [markdown]
# So we have cleaned our data.

# %% [markdown]
# According to the NAAC:
#
#
#     CGPA            GRADE
#     3.51 - 4.00	     A++
#     3.26 - 3.50	     A+
#     3.01 - 3.25	     A
#     2.76 - 3.00	     B++
#     2.51 - 2.75    	 B+
#     2.01 - 2.50	     B
#     1.51 - 2.00	     C

# %% [markdown]
# # COUNTPLOT for grades

# %%
grade = df['GRADE'].value_counts()

# %%
grade
# Out:
# B      2528
# A      1138
# B+      916
# B++     689
# C       642
# A+      234
# A++      51
# A         3
# Name: GRADE, dtype: int64

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.countplot(data=df, x='GRADE')
# Out:
# <AxesSubplot:xlabel='GRADE', ylabel='count'>

# %% [markdown]
# # Calculating average of CGPA scored

# %%
tot_cgpa=0
for num in df['CGPA']:
    num = float(num)
    tot_cgpa+=num
print(tot_cgpa)
# Out:
# 15904.730000000185

# %%
avg= tot_cgpa/df['CGPA'].shape[0]

# %%
avg
# Out:
# 2.5648653442993363

# %% [markdown]
# we can also use the other method to calculate its average and that is:

# %%
df['CGPA']= df['CGPA'].astype(float)
df['CGPA'].mean()
# Out:
# 2.5648653442993066

# %% [markdown]
# # Percentage of college who scored above and below average

# %%
above_avg=[]
for num in df['CGPA']:
    num = float(num)
    if num>avg:
        above_avg.append(num)
    else:
        pass
print((len(above_avg)/df['CGPA'].shape[0])*100 )
# Out:
# 49.10498306724722

# %% [markdown]
# So approx 49% colleges have CGPA below average

# %%
below_avg= 100-((len(above_avg)/df['CGPA'].shape[0])*100)

# %%
below_avg
# Out:
# 50.89501693275278

# %% [markdown]
# And approx 51% colleges have CGPA below average. So it is clear from this that there are more colleges whose CGPA is less than the average CGPA.

# %%
x = df['CGPA']>avg
y =np.array(x.value_counts())
y
# Out:
# array([3156, 3045], dtype=int64)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))

labels= ['Above avg', 'Below avg']
plt.pie(y, labels=labels, autopct='%1.1f%%', shadow = True, frame = True, wedgeprops={'edgecolor':'black'})
plt.legend()
plt.title('Percentage of college above and below Average')
plt.show()

# %% [markdown]
# # TOP 10 COLLEGES ACCORDING TO CGPA

# %%
top = df[df['CGPA']>avg].sort_values(by= 'CGPA', ascending=False)

# %%
top
# Out:
#                                              college name           state  \
# Sr.No.
# 4598    GOVERNMENT MOHINDRA COLLEGE, PATIALA – 147001 ...          Punjab
# 2414    RAJAGIRI COLLEGE OF SOCIAL SCIENCES,RAJAGIRI C...          Kerala
# 1957    B.M.S.COLLEGE OF ENGINEERING,P.O.BOX.NO.1908, ...       Karnataka
# 5072    SRI RAMAKRISHNA MISSION VIDYALAYA COLLEGE OF E...      Tamil Nadu
# 4829    S. S. JAIN SUBODH (P.G.) COLLEGE (AUTONOMOUS),...       Rajasthan
# ...                                                   ...             ...
# 4429    KHAIRA COLLEGE, BALASORE, BHUBANESWAR – 756048...          Odisha
# 2444    RAJADHANI INSTITUTE OF ENGINEERING AND TECHNOL...          Kerala
# 562     RAJ NARAIN COLLEGE, VAISHALI, 844101 (FIRST CY...           Bihar
# 93      BHAGAWAN SRI SATYASAI BABA DEGREE COLLEGE, TAD...  Andhra Pradesh
# 1967    SHARAVATHI FIRST GRADE COLLEGE KONANDUR,C K RO...       Karnataka
#
#         CGPA GRADE Accreditation validity
# Sr.No.
# ...

# %%
top[['college name', 'CGPA']].head(10)
# Out:
#                                              college name  CGPA
# Sr.No.
# 4598    GOVERNMENT MOHINDRA COLLEGE, PATIALA – 147001 ...  3.86
# 2414    RAJAGIRI COLLEGE OF SOCIAL SCIENCES,RAJAGIRI C...  3.83
# 1957    B.M.S.COLLEGE OF ENGINEERING,P.O.BOX.NO.1908, ...  3.83
# 5072    SRI RAMAKRISHNA MISSION VIDYALAYA COLLEGE OF E...  3.82
# 4829    S. S. JAIN SUBODH (P.G.) COLLEGE (AUTONOMOUS),...  3.82
# 4546    GANDHI INSTITUTE FOR TECHNOLOGY (GIFT),AT. GRA...  3.80
# 1862    ST. JOSEPH'S COLLEGE (AUTONOMOUS), LALBAGH ROA...  3.79
# 3370    MARATHA VIDYA PRASARAK SAMAJ'S K. R. T. ARTS, ...  3.79
# 2107    KRISTU JAYANTI COLLEGE,KRISTU JAYANTI COLLEGE,...  3.78
# 6079    ST. XAVIER’S COLLEGE (AUTONOMOUS), MOTHER TERE...  3.77

# %% [markdown]
# INSIGHTS: The above table mentions the top 10 colleges according to their CGPA.

# %%
yj = df['state'].value_counts()

# %%
plt.style.use('ggplot')
plt.figure(figsize= (15,15), dpi=200)
plt.barh(yj.index, yj.values)
plt.title('States with maximum colleges ')
plt.xlabel('Number of colleges')
plt.ylabel('States')

plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# INSIGHTS: Maharashtra, Karnataka, and Tamil Nadu are top 3 states with maximum colleges.

# %% [markdown]
# #  States with top 10 colleges

# %%
top_states= top[['college name', 'CGPA', 'state']].head(10)

# %%
top_states
# Out:
#                                              college name  CGPA        state
# Sr.No.
# 4598    GOVERNMENT MOHINDRA COLLEGE, PATIALA – 147001 ...  3.86       Punjab
# 2414    RAJAGIRI COLLEGE OF SOCIAL SCIENCES,RAJAGIRI C...  3.83       Kerala
# 1957    B.M.S.COLLEGE OF ENGINEERING,P.O.BOX.NO.1908, ...  3.83    Karnataka
# 5072    SRI RAMAKRISHNA MISSION VIDYALAYA COLLEGE OF E...  3.82   Tamil Nadu
# 4829    S. S. JAIN SUBODH (P.G.) COLLEGE (AUTONOMOUS),...  3.82    Rajasthan
# 4546    GANDHI INSTITUTE FOR TECHNOLOGY (GIFT),AT. GRA...  3.80       Odisha
# 1862    ST. JOSEPH'S COLLEGE (AUTONOMOUS), LALBAGH ROA...  3.79    Karnataka
# 3370    MARATHA VIDYA PRASARAK SAMAJ'S K. R. T. ARTS, ...  3.79  Maharashtra
# 2107    KRISTU JAYANTI COLLEGE,KRISTU JAYANTI COLLEGE,...  3.78    Karnataka
# 6079    ST. XAVIER’S COLLEGE (AUTONOMOUS), MOTHER TERE...  3.77  West Bengal

# %% [markdown]
# Top college according to the CGPA is present in the PUNJAB.

# %%
plt.figure(figsize=(10,6), dpi=200)
sns.countplot(data=top_states, x='state')
# Out:
# <AxesSubplot:xlabel='state', ylabel='count'>

# %% [markdown]
# Among top 10 colleges 3 are present in the Karnataka.
